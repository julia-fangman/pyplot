# %% [markdown]
# # Web Mining and Applied NLP (44-620)
#
# ## Matplotlib and pyplot
#
# ## Student Name: Julia Fangman
#
# ## Github Repo Link: https://github.com/julia-fangman/pyplot
#
# Perform the tasks described in the Markdown cells below.  When you have completed the assignment make sure your code cells have all been run (and have output beneath them) and ensure you have committed and pushed ALL of your changes to your assignment repository.
#
# Every question that requires you to write code will have a code cell underneath it; you may either write your entire solution in that cell or write it in a python file (`.py`), then import and run the appropriate code to answer the question.
#
# Do not use other external modules except `matplotlib` and `pyplot` (e.g. `math`, etc) for this assignment unless you are explicitly instructed to, though you may use built in python functions (`min`, `max`, etc) as you wish.
#
# For all of these questions, your plots must have an appropriate title and labeled axes.  Use the Matplotlib documentation as necessary to guide you through these exercises.

# %% [markdown]
# ## Prereqs Installed:

# %%
from collections import Counter
from random import randint
import matplotlib.pyplot as plt


print('All prereqs installed.')
# !pip list
# Out:
# All prereqs installed.
# Package                   Version
# ------------------------- ------------
# altair                    5.1.1
# altair-data-server        0.4.1
# altair-saver              0.5.0
# altair-viewer             0.4.0
# annotated-types           0.5.0
# antiorm                   1.2.1
# anyio                     4.0.0
# appdirs                   1.4.4
# appnope                   0.1.3
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.2.3
# asgiref                   3.7.2
# astroid                   2.15.6
# asttokens                 2.4.0
# async-lru                 2.0.4
# attrs                     23.1.0
# Babel                     2.12.1
# backcall                  0.2.0
# beautifulsoup4            4.12.2
# bleach                    6.0.0
# blis                      0.7.10
# catalogue                 2.0.9
# certifi                   2023.7.22
# cffi                      1.15.1
# charset-normalizer        3.2.0
# click                     8.1.7
# comm                      0.1.4
# confection                0.1.3
# contourpy                 1.1.0
# cycler                    0.11.0
# cymem                     2.0.7
# db                        0.1.1
# db-sqlite3                0.0.1
# debugpy                   1.7.0
# decorator                 5.1.1
# defusedxml                0.7.1
# dill                      0.3.7
# distlib                   0.3.8
# dodgy                     0.2.1
# dweepy                    0.3.0
# executing                 1.2.0
# fastjsonschema            2.18.0
# filelock                  3.13.1
# flake8                    5.0.4
# flake8-polyfill           1.0.2
# fonttools                 4.42.1
# fqdn                      1.5.1
# geographiclib             2.0
# geopy                     2.4.0
# gitdb                     4.0.10
# GitPython                 3.1.35
# h11                       0.14.0
# htmltools                 0.5.1
# idna                      3.4
# imageio                   2.31.3
# ipykernel                 6.25.2
# ipython                   8.15.0
# isoduration               20.11.0
# isort                     5.12.0
# jedi                      0.19.0
# Jinja2                    3.1.2
# joblib                    1.3.2
# json5                     0.9.14
# jsonpointer               2.4
# jsonschema                4.19.0
# jsonschema-specifications 2023.7.1
# jupyter_client            8.3.1
# jupyter_core              5.3.1
# jupyter-events            0.7.0
# jupyter-lsp               2.2.0
# jupyter_server            2.7.3
# jupyter_server_terminals  0.4.4
# jupyterlab                4.0.5
# jupyterlab-pygments       0.2.2
# jupyterlab_server         2.24.0
# kiwisolver                1.4.5
# langcodes                 3.3.0
# lazy-object-proxy         1.9.0
# linkify-it-py             2.0.3
# markdown-it-py            3.0.0
# MarkupSafe                2.1.3
# matplotlib                3.7.2
# matplotlib-inline         0.1.6
# mccabe                    0.7.0
# mdit-py-plugins           0.4.0
# mdurl                     0.1.2
# mistune                   3.0.1
# murmurhash                1.0.9
# mysql-connector-python    8.1.0
# nbclient                  0.7.4
# nbconvert                 7.8.0
# nbformat                  5.9.2
# nest-asyncio              1.5.7
# nltk                      3.8.1
# notebook_shim             0.2.3
# numpy                     1.25.2
# outcome                   1.2.0
# overrides                 7.4.0
# packaging                 23.1
# pandas                    2.1.1
# pandocfilters             1.5.0
# parso                     0.8.3
# pathy                     0.10.2
# pep8-naming               0.10.0
# pexpect                   4.8.0
# pickleshare               0.7.5
# Pillow                    10.0.0
# pip                       24.0
# platformdirs              3.10.0
# portpicker                1.6.0
# preshed                   3.0.8
# prometheus-client         0.17.1
# prompt-toolkit            3.0.36
# prospector                1.10.2
# protobuf                  4.21.12
# psutil                    5.9.5
# ptyprocess                0.7.0
# pure-eval                 0.2.2
# pycodestyle               2.9.1
# pycparser                 2.21
# pydantic                  2.3.0
# pydantic_core             2.6.3
# pydocstyle                6.3.0
# pyflakes                  2.5.0
# Pygments                  2.16.1
# PyHyphen                  4.0.3
# pylint                    2.17.5
# pylint-celery             0.3
# pylint-django             2.5.3
# pylint-flask              0.6
# pylint-plugin-utils       0.7
# pyparsing                 3.0.9
# PySocks                   1.7.1
# python-dateutil           2.8.2
# python-json-logger        2.0.7
# python-multipart          0.0.9
# pytz                      2023.3.post1
# PyYAML                    6.0.1
# pyzmq                     25.1.1
# questionary               2.0.1
# referencing               0.30.2
# regex                     2023.8.8
# requests                  2.31.0
# requirements-detector     1.2.2
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rpds-py                   0.10.2
# scikit-learn              1.3.1
# scipy                     1.11.2
# seaborn                   0.12.2
# selenium                  4.13.0
# semver                    3.0.1
# Send2Trash                1.8.2
# setoptconf-tmp            0.3.1
# setuptools                65.5.0
# shiny                     0.8.0
# six                       1.16.0
# smart-open                6.4.0
# smmap                     5.0.0
# sniffio                   1.3.0
# snowballstemmer           2.2.0
# sortedcontainers          2.4.0
# soupsieve                 2.5
# spacy                     3.6.1
# spacy-legacy              3.0.12
# spacy-loggers             1.0.5
# srsly                     2.4.7
# stack-data                0.6.2
# starlette                 0.37.1
# terminado                 0.17.1
# textatistic               0.0.1
# textblob                  0.17.1
# thinc                     8.1.12
# threadpoolctl             3.2.0
# tinycss2                  1.2.1
# toml                      0.10.2
# tomlkit                   0.12.1
# toolz                     0.12.0
# tornado                   6.3.3
# tqdm                      4.66.1
# traitlets                 5.9.0
# trio                      0.22.2
# trio-websocket            0.11.1
# typer                     0.9.0
# typing_extensions         4.7.1
# tzdata                    2023.3
# uc-micro-py               1.0.3
# uri-template              1.3.0
# urllib3                   2.0.4
# uvicorn                   0.27.1
# virtualenv                20.25.1
# voila                     0.5.2
# wasabi                    1.1.2
# watchfiles                0.21.0
# wcwidth                   0.2.6
# webcolors                 1.13
# webencodings              0.5.1
# websocket-client          1.6.3
# websockets                11.0.3
# wheel                     0.41.2
# wrapt                     1.15.0
# wsproto                   1.2.0

# %% [markdown]
# 1. Given the text below, create a bar plot (or a horizontal bar plot) that shows the frequency distribution of characters in the string.
# A dictionary has been created for you containing the characters and the frequencies of the characters.
# Make sure your bar plot has the bars labelled correctly (with the character it represents the frequency of).

# %%
from collections import Counter
TEXT = "At three o’clock precisely I was at Baker Street, but Holmes had not yet returned. The landlady informed me that he had left the house shortly after eight o’clock in the morning. I sat down beside the fire, however, with the intention of awaiting him, however long he might be. I was already deeply interested in his inquiry, for, though it was surrounded by none of the grim and strange features which were associated with the two crimes which I have already recorded, still, the nature of the case and the exalted station of his client gave it a character of its own. Indeed, apart from the nature of the investigation which my friend had on hand, there was something in his masterly grasp of a situation, and his keen, incisive reasoning, which made it a pleasure to me to study his system of work, and to follow the quick, subtle methods by which he disentangled the most inextricable mysteries. So accustomed was I to his invariable success that the very possibility of his failing had ceased to enter into my head.".lower()
letter_freq = dict(Counter(TEXT))

# make a bar plot with an appropriate title, correct xtick labels, and labeled axes

# %% [markdown]
# ## Question 1 Response & Output

# %%
sorted_freq = {k: v for k, v in sorted(letter_freq.items(), key=lambda item: item[0])}

plt.figure(figsize=(10, 8))
plt.bar(list(sorted_freq.keys()), list(sorted_freq.values()), color='pink')
plt.xlabel('Character')
plt.ylabel('Frequency')
plt.title('Frequency Distribution of Characters')
plt.xticks(rotation=90)  
for i, v in enumerate(sorted_freq.values()):
    plt.text(i, v + 0.2, str(v), ha='center', va='bottom', fontsize=8) 
plt.gca().set_facecolor('white')
plt.show()

# %% [markdown]
# 2. Generate a sequence of at least 5 random numbers (integers are fine), and visualize the data using both `scatter` and `plot` on different axes.  You may use the index of the value as its x value in the plot.

# %% [markdown]
# ## Question 2 Response & Output

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(1)  
random_numbers = np.random.randint(0, 200, size=10)

plt.rcParams['axes.facecolor'] = 'lightblue'

# Scatter plot
plt.figure(figsize=(10, 8))
plt.subplot(2, 1, 1) 
plt.scatter(range(len(random_numbers)), random_numbers, color='black', s=100)
plt.title('Scatter Plot')
plt.xlabel('Index')
plt.ylabel('Value')

# Line Plot
plt.subplot(2, 1, 2)  
plt.plot(range(len(random_numbers)), random_numbers, marker='o', color='black', linestyle='-')
plt.title('Line Plot')
plt.xlabel('Index')
plt.ylabel('Value')

plt.tight_layout()  
plt.show()

# %% [markdown]
# 3. Do the same question as above, but change the syle and color of both the scatter and the plot.

# %% [markdown]
# ## Question 3 Response & Output

# %%
np.random.seed(1)
random_numbers = np.random.randint(0, 200, size=10)

plt.rcParams['axes.facecolor'] = 'lightpink'

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

# Scatter plot
ax1.scatter(range(len(random_numbers)), random_numbers, color='yellow', marker='*', s=150)
ax1.set_title('Scatter Plot')
ax1.set_xlabel('Index')
ax1.set_ylabel('Value')

x_values = np.arange(len(random_numbers))

# Line Plot
ax2.plot(x_values, random_numbers, marker='o', color='yellow', linestyle='--')
ax2.set_title('Line Plot')
ax2.set_xlabel('Index')
ax2.set_ylabel('Value')

plt.tight_layout()  
plt.show()

# %% [markdown]
# 4. Given the data sets below, plot or scatter both on the same set of axes.  You are plotting the time it takes to execute a sorting algorithm on a list of a given size; your x axis should be the size, and the y axis is time.  Assume that `insertion_sort_times[i]` is how long it took to sort a list of length `sizes[i]`.  Add a legend to your plot showing which is insertion sort and which is merge sort.  Use the variable names to determine which data is which.

# %%
sizes = [10, 20, 50, 100, 1000, 5000]
insertion_sort_times = [0.0010252999999999998, 0.0027026999999999954, 0.010147200000000002, 0.0381137, 3.6303399, 91.2180796]
merge_sort_times = [0.00161889999999687, 0.003635600000009731, 0.0090655000000055, 0.020108000000007564, 0.2687474000000094, 1.6147050999999948]

# %% [markdown]
# ## Question 4 Response & Output

# %%
plt.figure(figsize=(10, 6))
plt.plot(sizes, insertion_sort_times, marker='o', color='lightblue', label='Insertion Sort')
plt.plot(sizes, merge_sort_times, marker='s', color='gray', label='Merge Sort')
plt.xlabel('Size')
plt.ylabel('Time (seconds)')
plt.title('Sorting Algorithm Performance')
plt.legend(loc='upper left')  
plt.gca().set_facecolor('white')  
plt.grid(False)  
plt.show()
